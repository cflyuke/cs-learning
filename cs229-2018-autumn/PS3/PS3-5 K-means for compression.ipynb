# %% [markdown]
# ## PS3-5 K-means for compression

# %% [markdown]
# ### (a)

# %%
# %run p05_kmeans.py
# Out:
# [INFO] Loaded small image with shape: (128, 128, 3)
# [INFO] Centroids initialized
# ...
# Updating centroids ...
# ...
# [INFO] Loaded large image with shape: (512, 512, 3)
# ...
# Updating large image ...
# ...

# %% [markdown]
# ### (b)

# %% [markdown]
# 由以前的3*8=24bit， 到现在的16，即4bit，可知图像压缩了6倍
